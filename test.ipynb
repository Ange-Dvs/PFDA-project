# %%
import pandas as pd

# %%
original_df = pd.read_csv('data/Impact_of_Remote_Work_on_Mental_Health.csv')

# %%
#original_df.describe()
print(original_df.columns)
original_df.describe()
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Job_Role', 'Industry',
#        'Years_of_Experience', 'Work_Location', 'Hours_Worked_Per_Week',
#        'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
#        'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')
#                Age  Years_of_Experience  Hours_Worked_Per_Week  \
# count  5000.000000          5000.000000            5000.000000
# mean     40.995000            17.810200              39.614600
# std      11.296021            10.020412              11.860194
# min      22.000000             1.000000              20.000000
# 25%      31.000000             9.000000              29.000000
# 50%      41.000000            18.000000              40.000000
# ...

# %%
print(original_df)
# Out:
#      Employee_ID  Age      Gender           Job_Role    Industry  \
# 0        EMP0001   32  Non-binary                 HR  Healthcare
# 1        EMP0002   40      Female     Data Scientist          IT
# 2        EMP0003   59  Non-binary  Software Engineer   Education
# 3        EMP0004   27        Male  Software Engineer     Finance
# 4        EMP0005   49        Male              Sales  Consulting
# ...          ...  ...         ...                ...         ...
# 4995     EMP4996   32        Male              Sales  Consulting
# 4996     EMP4997   39      Female              Sales  Healthcare
# 4997     EMP4998   42      Female              Sales  Healthcare
# 4998     EMP4999   27      Female              Sales  Healthcare
# 4999     EMP5000   29        Male                 HR          IT
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# ...

# %%
# checking some text fields to see what the high level data looks like
unique_jobs = original_df['Job_Role'].value_counts()
print(f'\n\t{unique_jobs}')

unique_industry = original_df['Industry'].value_counts()
print(f'\n\t{unique_industry}')
# Out:
# 	Job_Role
# Project Manager      738
# Sales                733
# Designer             723
# HR                   716
# Software Engineer    711
# Data Scientist       696
# Marketing            683
# Name: count, dtype: int64
#
# 	Industry
# Finance          747
# IT               746
# Healthcare       728
# Retail           726
# Education        690
# Manufacturing    683
# Consulting       680
# Name: count, dtype: int64

# %%
# checking some text fields to see what the high level data looks like
unique_gender = original_df['Gender'].value_counts()
print(f'\n\t{unique_gender}')

unique_work_location = original_df['Work_Location'].value_counts()
print(f'\n\t{unique_work_location}')
# Out:
# 	Gender
# Female               1274
# Male                 1270
# Prefer not to say    1242
# Non-binary           1214
# Name: count, dtype: int64
#
# 	Work_Location
# Remote    1714
# Hybrid    1649
# Onsite    1637
# Name: count, dtype: int64

# %% [markdown]
# Ideas for columns to compare/analyse:
#
# Physical_Activity vs Stress level
# Sleep_Quality vs Stress level
# Average stress level per work location type
# Access_to_Mental_Health_Resources vs Stress level
# Social_Isolation_Rating vs Stress level
#
# *May need to rethink the choice of dataset due to feeling of sparse number of columns with numeric data*
